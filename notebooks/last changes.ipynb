# %%
import pandas as pd

# %%
df3=pd.read_csv('../data/processed/Cleaned_file03.csv')
df6=pd.read_csv('../data/processed/Cleaned_file06.csv')

# %%
df6
# Out:
#         HP  melee attack  Remote attack  defense  Support  experience ratio  \
# 0      NaN  melee attack  Remote attack  defense  Support  experience ratio
# 1   8000.0           130            200      220       90                30
# 2    120.0           130            120      140       90                 1
# 3   6000.0           100            100      100      100                30
# 4    105.0           120            100      100      100                 1
# 5   6500.0           100            120      125       90                30
# 6    100.0           100            105      110       90                 1
# 7   5500.0           100            110      105      100                30
# 8    110.0           100            110      105      100                 1
# 9   6500.0           100            140      110      100                30
# 10   100.0           100            130      100      100                 1
#
# ...

# %%
df6_c=df6.copy()

# %%
df3_c=df3.copy()

# %%
df6_c=df6_c.drop(index=0)

# %%
df6_c=df6_c.reset_index(drop=True)

# %%
df6_c
# Out:
#        HP melee attack Remote attack defense Support experience ratio  \
# 0  8000.0          130           200     220      90               30
# 1   120.0          130           120     140      90                1
# 2  6000.0          100           100     100     100               30
# 3   105.0          120           100     100     100                1
# 4  6500.0          100           120     125      90               30
# 5   100.0          100           105     110      90                1
# 6  5500.0          100           110     105     100               30
# 7   110.0          100           110     105     100                1
# 8  6500.0          100           140     110     100               30
# 9   100.0          100           130     100     100                1
#
#   slow walking speed walking speed running speed riding speed Handling speed  \
# 0                 80            80           850         1100            465
# ...

# %%
df3_c
# Out:
#       ID     Chinese name              Name       CodeName OverrideNameTextID  \
# 0      1      mian youyou           lamball      sheepball        no_pal_name
# 1      2      naughty cat           cattiva        pinkcat        no_pal_name
# 2      3     pipi chicken           chikipi     chickenpal        no_pal_name
# 3      4   green leaf rat           lifmunk      carbunclo        no_pal_name
# 4      5       tinder fox          foxparks      kitsunebi        no_pal_name
# ..   ...              ...               ...            ...                ...
# 133  108  knight of light          paladius   saintcentaur        no_pal_name
# 134  109     chaos knight          necromus   blackcentaur        no_pal_name
# 135  110    winter caller       frostallion       icehorse        no_pal_name
# 136  110     night caller  frostallion noct  icehorse_dark        no_pal_name
# 137  111    vortex dragon          jetragon      jetdragon        no_pal_name
#
# ...

# %%
df3_c=df3_c.drop(index=0)
df3_c=df3_c.reset_index(drop=True)

# %%
df3_c.to_csv('../data/processed/Cleaned_file03e.csv')
df6_c.to_csv('../data/processed/Cleaned_file06e.csv')

# %%
df3
# Out:
#       ID     Chinese name              Name       CodeName  \
# 0     id     chinese name              name       codename
# 1      1      mian youyou           lamball      sheepball
# 2      2      naughty cat           cattiva        pinkcat
# 3      3     pipi chicken           chikipi     chickenpal
# 4      4   green leaf rat           lifmunk      carbunclo
# ..   ...              ...               ...            ...
# 134  108  knight of light          paladius   saintcentaur
# 135  109     chaos knight          necromus   blackcentaur
# 136  110    winter caller       frostallion       icehorse
# 137  110     night caller  frostallion noct  icehorse_dark
# 138  111    vortex dragon          jetragon      jetdragon
#
#      OverrideNameTextID  NamePrefixID  OverridePartnerSkillTextID  IsPal  \
# 0    overridenametextid  nameprefixid  overridepartnerskilltextid  ispal
# 1           no_pal_name  no_boss_name            no_partner_skill   true
# ...

# %%
df3_c
# Out:
#       ID     Chinese name              Name       CodeName OverrideNameTextID  \
# 0      1      mian youyou           lamball      sheepball        no_pal_name
# 1      2      naughty cat           cattiva        pinkcat        no_pal_name
# 2      3     pipi chicken           chikipi     chickenpal        no_pal_name
# 3      4   green leaf rat           lifmunk      carbunclo        no_pal_name
# 4      5       tinder fox          foxparks      kitsunebi        no_pal_name
# ..   ...              ...               ...            ...                ...
# 133  108  knight of light          paladius   saintcentaur        no_pal_name
# 134  109     chaos knight          necromus   blackcentaur        no_pal_name
# 135  110    winter caller       frostallion       icehorse        no_pal_name
# 136  110     night caller  frostallion noct  icehorse_dark        no_pal_name
# 137  111    vortex dragon          jetragon      jetdragon        no_pal_name
#
# ...

# %%
df3_c.isnull().values.any()
# Out:
# False

# %%
df3_c.isnull().sum()[df3_c.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df3_c = df3_c.dropna(axis=1, how='all')

# %%
df3_c['variant']=df3_c['variant'].fillna('no')
df3_c['nocturnal']=df3_c['nocturnal'].fillna('no')
df3_c['Riding sprint speed']=df3_c['Riding sprint speed'].fillna('cant_sprint')  
df3_c['Must bring entry 1']=df3_c['Must bring entry 1'].fillna('unspecified')
df3_c['Must bring entry 2']=df3_c['Must bring entry 2'].fillna('unspecified')
# Out:
# C:\Users\yamsq\AppData\Local\Temp\ipykernel_22008\2667349598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_c['variant']=df3_c['variant'].fillna('no')
# C:\Users\yamsq\AppData\Local\Temp\ipykernel_22008\2667349598.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_c['nocturnal']=df3_c['nocturnal'].fillna('no')
# C:\Users\yamsq\AppData\Local\Temp\ipykernel_22008\2667349598.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df3_c.to_csv('../data/processed/Cleaned_file03finalv2.csv', index=False)
df6_c.to_csv('../data/processed/Cleaned_file06finalv2.csv', index=False)

# %%
noms = [
    "Victor & Heterogeneous Griffin",
    "Heterogeneous Griffin",
    "Zoe & Lightning Bear",
    "Lightning Bear",
    "Marcus & Horus",
    "Horus",
    "Lily & Lily Queen",
    "lily queen",
    "Axel & Pollux",
    "Pollux"
]

# %%
assert len(noms) == len(df6_c), "La longueur de la liste 'noms' doit correspondre au nombre de lignes du DataFrame."

# %%
df6_c["name"] = noms

# %%
colonnes = ["name"] + [col for col in df6_c.columns if col != "name"]
df6_c = df6_c[colonnes]

# %%
df6_c
# Out:
#                              name      HP melee attack Remote attack defense  \
# 0  Victor & Heterogeneous Griffin  8000.0          130           200     220
# 1           Heterogeneous Griffin   120.0          130           120     140
# 2            Zoe & Lightning Bear  6000.0          100           100     100
# 3                  Lightning Bear   105.0          120           100     100
# 4                  Marcus & Horus  6500.0          100           120     125
# 5                           Horus   100.0          100           105     110
# 6               Lily & Lily Queen  5500.0          100           110     105
# 7                      lily queen   110.0          100           110     105
# 8                   Axel & Pollux  6500.0          100           140     110
# 9                          Pollux   100.0          100           130     100
#
#   Support experience ratio slow walking speed walking speed running speed  \
# ...
