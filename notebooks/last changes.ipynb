# %%
import pandas as pd

# %%
df3=pd.read_csv('../data/processed/Cleaned_file03.csv')
df6=pd.read_csv('../data/processed/Cleaned_file06.csv')

# %%
df6
# Out:
#         HP  melee attack  Remote attack  defense  Support  experience ratio  \
# 0      NaN  melee attack  Remote attack  defense  Support  experience ratio
# 1   8000.0           130            200      220       90                30
# 2    120.0           130            120      140       90                 1
# 3   6000.0           100            100      100      100                30
# 4    105.0           120            100      100      100                 1
# 5   6500.0           100            120      125       90                30
# 6    100.0           100            105      110       90                 1
# 7   5500.0           100            110      105      100                30
# 8    110.0           100            110      105      100                 1
# 9   6500.0           100            140      110      100                30
# 10   100.0           100            130      100      100                 1
#
# ...

# %%
df6_c=df6.copy()

# %%
df3_c=df3.copy()

# %%
df6_c=df6_c.drop(index=0)

# %%
df6_c=df6_c.reset_index(drop=True)

# %%
df6_c
# Out:
#        HP melee attack Remote attack defense Support experience ratio  \
# 0  8000.0          130           200     220      90               30
# 1   120.0          130           120     140      90                1
# 2  6000.0          100           100     100     100               30
# 3   105.0          120           100     100     100                1
# 4  6500.0          100           120     125      90               30
# 5   100.0          100           105     110      90                1
# 6  5500.0          100           110     105     100               30
# 7   110.0          100           110     105     100                1
# 8  6500.0          100           140     110     100               30
# 9   100.0          100           130     100     100                1
#
#   slow walking speed walking speed running speed riding speed Handling speed  \
# 0                 80            80           850         1100            465
# ...

# %%
df3_c
# Out:
#       ID     Chinese name              Name       CodeName OverrideNameTextID  \
# 0      1      mian youyou           lamball      sheepball        no_pal_name
# 1      2      naughty cat           cattiva        pinkcat        no_pal_name
# 2      3     pipi chicken           chikipi     chickenpal        no_pal_name
# 3      4   green leaf rat           lifmunk      carbunclo        no_pal_name
# 4      5       tinder fox          foxparks      kitsunebi        no_pal_name
# ..   ...              ...               ...            ...                ...
# 133  108  knight of light          paladius   saintcentaur        no_pal_name
# 134  109     chaos knight          necromus   blackcentaur        no_pal_name
# 135  110    winter caller       frostallion       icehorse        no_pal_name
# 136  110     night caller  frostallion noct  icehorse_dark        no_pal_name
# 137  111    vortex dragon          jetragon      jetdragon        no_pal_name
#
# ...

# %%
df3_c=df3_c.drop(index=0)
df3_c=df3_c.reset_index(drop=True)

# %%
df3_c.to_csv('../data/processed/Cleaned_file03e.csv')
df6_c.to_csv('../data/processed/Cleaned_file06e.csv')
